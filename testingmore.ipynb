# %%
import torch
import utils
import numpy as np
import gpflow
import matplotlib.pyplot as plt

class DefaultMethodClass():
    def __init__(self, func_class,
                 limits
                 ):
        self.method_name = 'Default Method Class'


        self.X_train = []
        self.y_train = []

        self.func_obj = func_class()

        self.limits = limits
        self.dims = len(limits)
        self.limit_difs = [abs(l1-l2) for l1,l2 in limits]
        self.limit_mins = [min(l1,l2) for l1, l2 in limits]

        return
    
    def get_regret(self):
        if self.func_obj.regret_arr:
            return np.array(self.func_obj.regret_arr)
        else:
            print('Funciton to minimise not given or Search method')

    def eval_sample(self, sample):
        try:
            self.X_train = np.vstack((self.X_train, sample))
            self.y_train = np.vstack((self.y_train , self.func_obj.eval(sample)))
        except:
            self.X_train = sample
            self.y_train = self.func_obj.eval(sample)


class AverageMethod():
    def __init__(self, 
                 method_class : DefaultMethodClass,
                 func_class : utils.test_functions.FuncToMinimise,
                 n_method_instances : int = 30):
        self.method_objs = [method_class(func_class = func_class) for _ in range(n_method_instances)]
        self.sum_regret = []
        self.get_sum_regret()

        self.mean_regret = self.sum_regret / n_method_instances

    def get_sum_regret(self):
        self.sum_regret = self.method_objs[0].get_regret()
        for meth in self.method_objs[1:]:
            self.sum_regret += meth.get_regret()

    def get_result(self):
        return {'name': self.method_objs[0].method_name,
                'regret':self.mean_regret}

class NormalGp(DefaultMethodClass):
    def __init__(self, func_class : utils.test_functions.FuncToMinimise,
                 n_iters = 200,
                 n_random_evals = 20,
                 limits : list[tuple[float]] = [(-5.0,10.0),(0.0,15.0)]):
        
        super().__init__(func_class, limits)

        self.n_iters = n_iters - n_random_evals

        self.initial_random_evals(n_random_evals)

        self.iter_func_evals()

        self.method_name = "GP"

    
    def initial_random_evals(self, n_rand):
        samples = (np.random.rand(n_rand, self.dims) * self.limit_difs) + self.limit_mins
        for x in samples:
            self.eval_sample(x)
    
    def get_gp(self):
        model = gpflow.models.GPR(
            (self.X_train, self.y_train),
            kernel = gpflow.kernels.Matern52())
        opt = gpflow.optimizers.Scipy()
        opt.minimize(model.training_loss, model.trainable_variables)
        return model

    def gen_sample(self):
        gp = self.get_gp()
        acq = utils.acq_functions.EI(gp, self.limits)
        
        x = torch.tensor([0.0,0.0], requires_grad=True) # this should prob be random
        optimizer = torch.optim.LBFGS([x], lr=1.0, max_iter = 100, history_size=10)

        def closure(opt = optimizer, func = acq.sample, x = x):
            opt.zero_grad()
            loss = func(x)
            loss.backward()
            return loss
        
        for _ in range(10):
            optimizer.step(closure)
        print(x.data)
        return x.data
            

    def iter_func_evals(self):
        for i in range(self.n_iters):
            try:
                if i%(self.n_iters//10) == 0:
                    print(f'{i/(self.n_iters)*100} % done')
            except:
                pass
            sample = self.gen_sample()
            self.eval_sample(sample)
        print('Finished Evaling a GP')

class AverageMethod():
    def __init__(self, 
                 method_class : DefaultMethodClass,
                 func_class : utils.test_functions.FuncToMinimise,
                 n_method_instances : int = 30):
        self.method_objs = [method_class(func_class = func_class) for _ in range(n_method_instances)]
        self.sum_regret = []
        self.get_sum_regret()

        self.mean_regret = self.sum_regret / n_method_instances

    def get_sum_regret(self):
        self.sum_regret = self.method_objs[0].get_regret()
        for meth in self.method_objs[1:]:
            self.sum_regret += meth.get_regret()

    def get_result(self):
        return {'name': self.method_objs[0].method_name,
                'regret':self.mean_regret}
    
def plot_results(results):
    for result in results:
        plt.plot(result['regret'], label=result['name'])
        plt.legend()
    plt.yscale(value="log")
    plt.plot()

def main():
    res_arr = []
    gp = AverageMethod(NormalGp, 
                  utils.test_functions.Branin,
                  n_method_instances=1)
    res_arr.append(gp.get_result())
    plot_results(res_arr)
    return

if __name__ == '__main__':
    main()
# Out:
# 0.0 % done
# c:\Users\seanp\OneDrive\Desktop\my_repos\AFSMC\utils\acq_functions.py:29: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   x = torch.tensor(x, dtype=torch.float64)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[3], line 158
#     155     return
#     157 if __name__ == '__main__':
# --> 158     main()
#
# Cell In[3], line 150, in main()
#     148 def main():
#     149     res_arr = []
# --> 150     gp = AverageMethod(NormalGp,
#     151                   utils.test_functions.Branin,
#     152                   n_method_instances=1)
#     153     res_arr.append(gp.get_result())
#     154     plot_results(res_arr)
#
# Cell In[3], line 126, in AverageMethod.__init__(self, method_class, func_class, n_method_instances)
#     122 def __init__(self,
#     123              method_class : DefaultMethodClass,
#     124              func_class : utils.test_functions.FuncToMinimise,
#     125              n_method_instances : int = 30):
# --> 126     self.method_objs = [method_class(func_class = func_class) for _ in range(n_method_instances)]
#     127     self.sum_regret = []
#     128     self.get_sum_regret()
#
# Cell In[3], line 126, in <listcomp>(.0)
#     122 def __init__(self,
#     123              method_class : DefaultMethodClass,
#     124              func_class : utils.test_functions.FuncToMinimise,
#     125              n_method_instances : int = 30):
# --> 126     self.method_objs = [method_class(func_class = func_class) for _ in range(n_method_instances)]
#     127     self.sum_regret = []
#     128     self.get_sum_regret()
#
# Cell In[3], line 73, in NormalGp.__init__(self, func_class, n_iters, n_random_evals, limits)
#      69 self.n_iters = n_iters - n_random_evals
#      71 self.initial_random_evals(n_random_evals)
# ---> 73 self.iter_func_evals()
#      75 self.method_name = "GP"
#
# Cell In[3], line 117, in NormalGp.iter_func_evals(self)
#     115     except:
#     116         pass
# --> 117     sample = self.gen_sample()
#     118     self.eval_sample(sample)
#     119 print('Finished Evaling a GP')
#
# Cell In[3], line 105, in NormalGp.gen_sample(self)
#     102     return loss
#     104 for _ in range(10):
# --> 105     optimizer.step(closure)
#     106 print(x.data)
#     107 return x.data
#
# File c:\Users\seanp\OneDrive\Desktop\my_repos\AFSMC\.venv\Lib\site-packages\torch\optim\optimizer.py:487, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     482         else:
#     483             raise RuntimeError(
#     484                 f"{func} must return None or a tuple of (new_args, new_kwargs), but got {result}."
#     485             )
# --> 487 out = func(*args, **kwargs)
#     488 self._optimizer_step_code()
#     490 # call optimizer step post hooks
#
# File c:\Users\seanp\OneDrive\Desktop\my_repos\AFSMC\.venv\Lib\site-packages\torch\utils\_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File c:\Users\seanp\OneDrive\Desktop\my_repos\AFSMC\.venv\Lib\site-packages\torch\optim\lbfgs.py:330, in LBFGS.step(self, closure)
#     327 state.setdefault("n_iter", 0)
#     329 # evaluate initial f(x) and df/dx
# --> 330 orig_loss = closure()
#     331 loss = float(orig_loss)
#     332 current_evals = 1
#
# File c:\Users\seanp\OneDrive\Desktop\my_repos\AFSMC\.venv\Lib\site-packages\torch\utils\_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# Cell In[3], line 100, in NormalGp.gen_sample.<locals>.closure(opt, func, x)
#      98 def closure(opt = optimizer, func = acq.sample, x = x):
#      99     opt.zero_grad()
# --> 100     loss = func(x)
#     101     loss.backward()
#     102     return loss
#
# File c:\Users\seanp\OneDrive\Desktop\my_repos\AFSMC\utils\acq_functions.py:34, in EI.sample(self, x)
#      32     lower_bound = torch.tensor(self.limits[0], dtype=torch.float64)
#      33     upper_bound = torch.tensor(self.limits[1], dtype=torch.float64)
# ---> 34     is_within_limits = torch.all((x >= lower_bound) & (x <= upper_bound), dim=1)
#      35 else:
#      36     is_within_limits = torch.ones(x.shape[0], dtype=torch.bool)
#
# IndexError: Dimension out of range (expected to be in range of [-1, 0], but got 1)
